# %%
import csv
import pandas as pd
from mining_utils import *

# %%
import pandas as pd
df = pd.read_csv('./sequential/tf_descp_freq5_len2.csv')
seq_list = df['sequence'] #you can also use df['column_name']

# %%
replace_dict = {
    r',\s': ',',
    r'\[': '',
    r'\]': '',
    r'\'': ''

}

# %%
len(set(replace_symbol(str(seq_list[1]), replace_dict).split(',')))
# Out:
# 2

# %%
set_list = []
for seq in seq_list:
    tmp_set = set(replace_symbol(seq, replace_dict).split(','))
    if len(tmp_set)>1:
        
        # check if already exist
        if tmp_set in set_list:
            print(tmp_set)
        else:
            set_list.append(tmp_set)

# %%
set_list
# Out:
# [{'name', 'operation'},
#  {'name', 'optional'},
#  {'name', 'operation', 'optional'},
#  {'SOME_DTYPE', 'tensor'},
#  {'SOME_DTYPE', 'optional'},
#  {'SOME_DTYPE', 'tensor'},
#  {'SOME_DTYPE', 'must'},
#  {'shape', 'tensor'},
#  {'tensor', 'type'},
#  {'d', 'tensor'},
#  {'SOME_DTYPE', 'one'},
#  {'SOME_DTYPE', 'must'},
#  {'must', 'one'},
#  {'SOME_DTYPE', 'following'},
#  {'SOME_DTYPE', 'must'},
#  {'SOME_DTYPE', 'following', 'one'},
#  {'following', 'must'},
#  {'SOME_DTYPE', 'following', 'must', 'one'},
#  {'SOME_DTYPE', 'one'},
#  {'SOME_DTYPE', 'following'},
#  {'SOME_DTYPE', 'following', 'must', 'one'},
#  {'SOME_DTYPE', 'following'},
#  {'SOME_DTYPE', 'following', 'must', 'one'},
#  {'SOME_DTYPE', 'type'},
#  {'SOME_DTYPE', 'tensor', 'type'},
#  {'SOME_DTYPE', 'tensor'},
#  {'SOME_DTYPE', 'must'},
#  {'name', 'optional'},
#  {'SOME_DTYPE', 'following'},
#  {'input', 'tensor'},
#  {'SOME_DTYPE', 'following', 'must', 'one'},
#  {'d', 'shape'},
#  {'SOME_DTYPE', 'shape'},
#  {'SOME_DTYPE', 'd'},
#  {'SOME_DTYPE', 'bfloat'},
#  {'SOME_DTYPE', 'must'},
#  {'SOME_DTYPE', 'bfloat', 'following', 'must', 'one'},
#  {'SOME_DTYPE', 'bfloat'},
#  {'SOME_DTYPE', 'bfloat', 'following', 'must', 'one'},
#  {'SOME_DTYPE', 'bfloat'},
#  {'optional', 'tensor'},
#  {'SOME_DTYPE', 'bfloat', 'following', 'must', 'one'},
#  {'SOME_DTYPE', 'must'},
#  {'SOME_DTYPE', 'following', 'must', 'one'},
#  {'SOME_DTYPE', 'following', 'must', 'one'},
#  {'batch', 'shape'},
#  {'tensor', 'whose'},
#  {'SOME_DTYPE', 'value'},
#  {'SOME_DTYPE', 'length'},
#  {'SOME_DTYPE', 'number'},
#  {'tensor', 'variable'},
#  {'dimension', 'input'},
#  {'SOME_DTYPE', 'tf'},
#  {'must', 'type'},
#  {'SOME_DTYPE', 'type'},
#  {'d', 'shape', 'tensor'},
#  {'SOME_DTYPE', 'bfloat'},
#  {'SOME_DTYPE', 'bfloat', 'following', 'must', 'one'},
#  {'SOME_DTYPE', 'name'},
#  {'dimension', 'tensor'},
#  {'SOME_DTYPE', 'tf'},
#  {'SOME_DTYPE', 'values'},
#  {'height', 'width'},
#  {'SOME_DTYPE', 'specifying'},
#  {'SOME_DTYPE', 'default'},
#  {'SOME_DTYPE', 'objects'},
#  {'SOME_DTYPE', 'python'},
#  {'SOME_DTYPE', 'optional'},
#  {'must', 'tensor'},
#  {'SOME_DTYPE', 'shape', 'tensor'},
#  {'dimensions', 'must'},
#  {'SOME_DTYPE', 'bfloat'},
#  {'batch_size', 'tensor'},
#  {'SOME_DTYPE', 'must'},
#  {'SOME_DTYPE', 'bfloat', 'following', 'must', 'one'},
#  {'SOME_DTYPE', 'length'},
#  {'SOME_DTYPE', 'added'},
#  {'shape', 'tensor'},
#  {'returned', 'tensor'},
#  {'SOME_DTYPE', 'representing'},
#  {'rank', 'tensor'},
#  {'SOME_DTYPE', 'collections'},
#  {'SOME_DTYPE', 'd', 'tensor'},
#  {'dimensions', 'tensor'},
#  {'SOME_DTYPE', 'following', 'must', 'one'},
#  {'SOME_DTYPE', 'collections', 'optional'},
#  {'SOME_DTYPE', 'input'},
#  {'see', 'tf'},
#  {'added', 'optional'},
#  {'default', 'none'},
#  {'name', 'tensor'},
#  {'SOME_DTYPE', 'feature'},
#  {'batch_size', 'shape'},
#  {'SOME_DTYPE', 'added', 'collections', 'optional'},
#  {'SOME_DTYPE', 'valid'},
#  {'SOME_DTYPE', 'whether'},
#  {'SOME_DTYPE', 'flag'},
#  {'batch', 'd'},
#  {'batch', 'tensor'},
#  {'SOME_DTYPE', 'bfloat'},
#  {'defaults', 'false'},
#  {'details', 'see'},
#  {'python', 'tensor'},
#  {'SOME_DTYPE', 'bfloat', 'following', 'must', 'one'},
#  {'operation', 'optional'},
#  {'SOME_DTYPE', 'must'},
#  {'dimension', 'tensor'},
#  {'output', 'tensor'},
#  {'SOME_DTYPE', 'type'},
#  {'SOME_DTYPE', 'bfloat', 'following', 'must', 'one'},
#  {'SOME_DTYPE', 'bfloat', 'following', 'must', 'one'},
#  {'default', 'value'},
#  {'objects', 'tensor'},
#  {'SOME_DTYPE', 'tensor'},
#  {'tensor', 'values'},
#  {'batch_size', 'shape', 'tensor'},
#  {'broadcastable', 'tensor'},
#  {'SOME_DTYPE', 'python'},
#  {'name', 'operation', 'optional'},
#  {'SOME_DTYPE', 'following', 'must', 'one'},
#  {'dimension', 'last'},
#  {'representing', 'tensor'},
#  {'SOME_DTYPE', 'tensor'},
#  {'batch', 'd', 'shape'},
#  {'dimension', 'size'},
#  {'dimension', 'window'},
#  {'SOME_DTYPE', 'bfloat'},
#  {'SOME_DTYPE', 'tensor'},
#  {'SOME_DTYPE', 'objects', 'tensor'},
#  {'SOME_DTYPE', 'must'},
#  {'SOME_DTYPE', 'bfloat', 'following', 'must', 'one'},
#  {'dimension', 'must'},
#  {'dimension', 'input', 'window'},
#  {'name', 'returned'},
#  {'SOME_DTYPE', 'tensor'},
#  {'SOME_DTYPE', 'message'},
#  {'must', 'rank'},
#  {'dimensions', 'must'},
#  {'corresponding', 'tensor'},
#  {'labels', 'tensor'},
#  {'tensor', 'value'},
#  {'SOME_DTYPE', 'single'},
#  {'SOME_DTYPE', 'must'},
#  {'batch', 'channels'},
#  {'algorithm', 'padding'},
#  {'number', 'tensor'},
#  {'SOME_DTYPE', 'must'},
#  {'SOME_DTYPE', 'following', 'must', 'one'},
#  {'batch', 'height', 'width'},
#  {'height', 'shape', 'width'},
#  {'channels_first', 'channels_last'},
#  {'dimensions', 'tensor', 'whose'},
#  {'match', 'must'},
#  {'either', 'tensor'},
#  {'dtype', 'tensor'},
#  {'SOME_DTYPE', 'number'},
#  {'SOME_DTYPE', 'number', 'tensor'},
#  {'must', 'range'},
#  {'must', 'tensor', 'whose'},
#  {'dimension', 'tensor', 'whose'},
#  {'d', 'tensor'},
#  {'SOME_DTYPE', 'length'},
#  {'defaults', 'tf'},
#  {'SOME_DTYPE', 'following', 'must', 'one'},
#  {'channels', 'shape'},
#  {'either', 'must'},
#  {'dimensions', 'must', 'tensor', 'whose'},
#  {'SOME_DTYPE', 'dtype'},
#  {'SOME_DTYPE', 'none'},
#  {'shape', 'type'},
#  {'input', 'must'},
#  {'d', 'type'},
#  {'dimension', 'either'},
#  {'e', 'g'},
#  {'e', 'must'},
#  {'SOME_DTYPE', 'variable'},
#  {'broadcastable', 'must'},
#  {'data', 'format'},
#  {'dimension', 'dimensions'},
#  {'d', 'height', 'width'},
#  {'SOME_DTYPE', 'shape'},
#  {'channels', 'height', 'width'},
#  {'shape', 'tensor', 'type'},
#  {'data', 'tensor'},
#  {'SOME_DTYPE', 'number', 'tensor'},
#  {'tensor', 'values'},
#  {'input', 'output'},
#  {'corresponding', 'must'},
#  {'SOME_DTYPE', 'd', 'tensor'},
#  {'default', 'dimensions'},
#  {'tensor', 'tf'},
#  {'d', 'shape'},
#  {'size', 'tensor'},
#  {'optional', 'tf'},
#  {'SOME_DTYPE', 'python', 'tensor'},
#  {'SOME_DTYPE', 'batch'},
#  {'SOME_DTYPE', 'prefix'},
#  {'labels', 'must'},
#  {'e', 'must'},
#  {'m', 'shape'},
#  {'dimension', 'e'},
#  {'labels', 'must'},
#  {'input', 'stride'},
#  {'SOME_DTYPE', 'd'},
#  {'must', 'range', 'rank'},
#  {'broadcastable', 'e', 'either', 'must'},
#  {'broadcastable', 'dimension', 'e', 'must'},
#  {'dimension', 'must'},
#  {'either', 'must'},
#  {'batch', 'tensor'},
#  {'dimension', 'input', 'tensor'},
#  {'d', 'height', 'shape', 'width'},
#  {'either', 'rank'},
#  {'must', 'rank'},
#  {'dimension', 'rank'},
#  {'length', 'true'},
#  {'either', 'labels'},
#  {'corresponding', 'either'},
#  {'either', 'rank', 'tensor', 'whose'},
#  {'either', 'rank', 'tensor', 'whose'},
#  {'batch', 'shape', 'tensor'},
#  {'d', 'shape', 'tensor'},
#  {'e', 'tensor'},
#  {'output', 'tensor'},
#  {'name', 'returned', 'tensor'},
#  {'e', 'optional'},
#  {'SOME_DTYPE', 'containing'},
#  {'must', 'range', 'rank'},
#  {'broadcastable',
#   'corresponding',
#   'dimension',
#   'dimensions',
#   'e',
#   'either',
#   'must'},
#  {'d', 'tensor', 'type'},
#  {'SOME_DTYPE', 'tf'},
#  {'in_channels', 'shape'},
#  {'random', 'seed'},
#  {'dimension', 'sliding', 'window'},
#  {'labels', 'rank', 'tensor'},
#  {'shape', 'tensor'},
#  {'containing', 'tensor'},
#  {'ssparsetensor', 'tensor'},
#  {'corresponding', 'optional'},
#  {'SOME_DTYPE', 'tensor'},
#  {'SOME_DTYPE', 'batch_size'},
#  {'must', 'values'},
#  {'SOME_DTYPE', 'bfloat', 'following', 'must', 'one'},
#  {'batch', 'shape'},
#  {'SOME_DTYPE', 'dtype'},
#  {'tensor', 'window'},
#  {'message', 'prefix'},
#  {'dimension', 'input', 'sliding', 'window'},
#  {'optional', 'whose'},
#  {'optional', 'rank'},
#  {'dimensions', 'optional'},
#  {'SOME_DTYPE', 'bfloat'},
#  {'SOME_DTYPE', 'dimension'},
#  {'SOME_DTYPE', 'default', 'message', 'prefix'},
#  {'tensor', 'type'},
#  {'classes', 'number'},
#  {'d', 'size'},
#  {'length', 'reduced', 'true'},
#  {'batch', 'height', 'shape', 'width'},
#  {'e', 'labels'},
#  {'dimension', 'input', 'sliding', 'stride', 'window'},
#  {'optional', 'tensor', 'whose'},
#  {'must', 'optional'},
#  {'SOME_DTYPE', 'either'},
#  {'SOME_DTYPE', 'bfloat', 'following', 'must', 'one'},
#  {'SOME_DTYPE', 'bfloat', 'following', 'must', 'one'},
#  {'broadcastable', 'e', 'either', 'labels', 'must'},
#  {'broadcastable', 'dimension', 'e', 'labels', 'must'},
#  {'broadcastable', 'dimension', 'labels', 'must'},
#  {'dimension', 'labels', 'must'},
#  {'must', 'shape'},
#  {'batch', 'channels', 'height', 'width'},
#  {'dimension', 'must'},
#  {'dimensions', 'rank'},
#  {'batch', 'channels', 'shape'},
#  {'channels', 'height', 'shape', 'width'},
#  {'axis', 'tensor'},
#  {'tensor', 'x'},
#  {'SOME_DTYPE', 'tensor', 'type'},
#  {'either', 'labels', 'rank', 'tensor', 'whose'},
#  {'broadcastable', 'optional', 'tensor'},
#  {'either', 'optional'},
#  {'SOME_DTYPE', 'bfloat'},
#  {'SOME_DTYPE', 'representing', 'tensor'},
#  {'SOME_DTYPE', 'returned'},
#  {'SOME_DTYPE', 'one'},
#  {'broadcastable',
#   'corresponding',
#   'dimension',
#   'dimensions',
#   'e',
#   'either',
#   'labels',
#   'must'},
#  {'data', 'format'},
#  {'batch', 'depth'},
#  {'dimension', 'value'},
#  {'dimensions', 'length'},
#  {'must', 'rank'},
#  {'dimensions', 'rank'},
#  {'dimension', 'rank'},
#  {'dimension', 'must', 'rank'},
#  {'e', 'rank'},
#  {'dimension', 'either', 'labels'},
#  {'e', 'either'},
#  {'SOME_DTYPE', 'single'},
#  {'dimension', 'labels', 'must'},
#  {'dimension', 'input', 'tensor', 'window'},
#  {'qint', 'quint'},
#  {'qint', 'quint'},
#  {'n', 'tensor'},
#  {'broadcastable',
#   'corresponding',
#   'dimension',
#   'dimensions',
#   'e',
#   'either',
#   'must',
#   'optional',
#   'rank',
#   'tensor',
#   'whose'},
#  {'SOME_DTYPE', 'python'},
#  {'SOME_DTYPE', 'tf'},
#  {'SOME_DTYPE', 'bfloat', 'following', 'must', 'one'},
#  {'batch', 'data'},
#  {'batch', 'dimensions'},
#  {'batch', 'd', 'tensor'},
#  {'batch', 'shape'},
#  {'number', 'python'},
#  {'nchw', 'nhwc'},
#  {'shape', 'tensor'},
#  {'optional', 'tensor'},
#  {'name', 'prefix'},
#  {'labels', 'optional'},
#  {'SOME_DTYPE', 'output'},
#  {'SOME_DTYPE', 'used'},
#  {'SOME_DTYPE', 'qint'},
#  {'SOME_DTYPE', 'd', 'shape'},
#  {'channels', 'd'},
#  {'entries', 'tensor'},
#  {'dimension', 'first'},
#  {'SOME_DTYPE', 'shape', 'tensor'},
#  {'shape', 'tensor'},
#  {'tensor', 'tf'},
#  {'labels', 'tensor'},
#  {'predictions', 'tensor'},
#  {'tensor', 'width'},
#  {'SOME_DTYPE', 'qint', 'quint'},
#  {'SOME_DTYPE', 'qint', 'quint'},
#  {'SOME_DTYPE', 'indicating'},
#  {'SOME_DTYPE', 'returns'},
#  {'dimensions', 'none'},
#  {'batch', 'd', 'height', 'width'},
#  {'dimensions', 'length', 'true'},
#  {'SOME_DTYPE', 'tf'},
#  {'dtype', 'tf'},
#  {'applied', 'function'},
#  {'n', 'shape'},
#  {'single', 'value'},
#  {'labels', 'must'},
#  {'height', 'tensor', 'width'},
#  {'name', 'prefix', 'tensor'},
#  {'SOME_DTYPE', 'number'},
#  {'SOME_DTYPE', 'function'},
#  {'SOME_DTYPE', 'axis'},
#  {'defaults', 'true'},
#  {'must', 'x'},
#  {'data_format', 'dimension'},
#  {'d', 'tensor'},
#  {'channels', 'd', 'height', 'width'},
#  {'d', 'in_channels'},
#  {'dimensions', 'length', 'reduced', 'true'},
#  {'either', 'valid'},
#  {'SOME_DTYPE', 'either'},
#  {'nested', 'tensor'},
#  {'many', 'tensor'},
#  {'floating', 'point'},
#  {'along', 'axis'},
#  {'axis', 'input'},
#  {'print', 'tensor'},
#  {'reduce', 'tensor'},
#  {'height', 'shape', 'tensor', 'width'},
#  {'input', 'tensor'},
#  {'SOME_DTYPE', 'optional', 'tf'},
#  {'broadcastable',
#   'corresponding',
#   'dimension',
#   'dimensions',
#   'e',
#   'either',
#   'labels',
#   'must',
#   'optional',
#   'rank',
#   'tensor',
#   'whose'},
#  {'broadcastable',
#   'dimension',
#   'either',
#   'labels',
#   'must',
#   'optional',
#   'rank',
#   'tensor',
#   'whose'},
#  {'SOME_DTYPE', 'number', 'tensor'},
#  {'SOME_DTYPE', 'python', 'tensor'},
#  {'SOME_DTYPE', 'tensor', 'type'},
#  {'SOME_DTYPE', 'use'},
#  {'SOME_DTYPE', 'dimensions'},
#  {'SOME_DTYPE', 'size'},
#  {'see', 'value'},
#  {'dimensions', 'values'},
#  {'SOME_DTYPE', 'defaults'},
#  {'type', 'x'},
#  {'must', 'tensor'},
#  {'batch', 'd', 'shape', 'tensor'},
#  {'channels', 'd', 'shape'},
#  {'batch', 'd', 'height', 'shape', 'width'},
#  {'compat', 'tf', 'v'},
#  {'nn', 'tf'},
#  {'batch', 'channels', 'height', 'shape', 'width'},
#  {'shape', 'values'},
#  {'corresponding', 'labels'},
#  {'representing', 'shape'},
#  {'e', 'labels'},
#  {'classes', 'target'},
#  {'name', 'optional', 'tensor'},
#  {'SOME_DTYPE', 'type'},
#  {'SOME_DTYPE', 'x'},
#  {'SOME_DTYPE', 'must'},
#  {'none', 'value'},
#  {'SOME_DTYPE', 'following', 'must', 'one', 'qint'},
#  {'default', 'dimensions', 'none'},
#  {'batch', 'in_channels'},
#  {'batch', 'format'},
#  {'d', 'height', 'shape', 'tensor', 'width'},
#  {'dtype', 'tf'},
#  {'shape', 'tensor'},
#  {'size', 'tensor'},
#  {'entries', 'many', 'print', 'tensor'},
#  {'name', 'op'},
#  {'name', 'prefix', 'returned', 'tensor'},
#  {'SOME_DTYPE', 'number', 'python', 'tensor'},
#  {'SOME_DTYPE', 'specifying'},
#  {'SOME_DTYPE', 'column'},
#  {'SOME_DTYPE', 'names'},
#  {'SOME_DTYPE', 'data'},
#  {'SOME_DTYPE', 'metric'},
#  {'SOME_DTYPE', 'following', 'must', 'one', 'qint', 'quint'},
#  {'SOME_DTYPE', 'following', 'must', 'one', 'qint', 'quint'},
#  {'broadcastable',
#   'corresponding',
#   'dimension',
#   'dimensions',
#   'e',
#   'either',
#   'labels',
#   'must'},
#  {'default', 'dimensions', 'none', 'reduces'},
#  {'data', 'order'},
#  {'batch', 'in_width'},
#  {'dimensions', 'reduce'},
#  {'channels', 'd', 'height', 'shape', 'width'},
#  {'SOME_DTYPE', 'dtype'},
#  {'function', 'tensor'},
#  {'default', 'n'},
#  {'height', 'width'},
#  {'returns', 'tensor'},
#  {'in_channels', 'shape', 'tensor'},
#  {'length', 'tensor'},
#  {'first', 'tensor'},
#  {'name', 'scope'},
#  {'SOME_DTYPE', 'qint'},
#  {'SOME_DTYPE', 'columns'},
#  {'SOME_DTYPE', 'n'},
#  {'SOME_DTYPE', 'either', 'valid'},
#  {'type', 'use'},
#  {'number', 'per'},
#  {'data', 'dataset'},
#  {'dimension', 'filter'},
#  {'d', 'in_channels', 'shape'},
#  {'d', 'dimension'},
#  {'data', 'tf'},
#  {'batch', 'shape'},
#  {'channels', 'shape'},
#  {'channels', 'shape'},
#  {'details', 'see', 'tf'},
#  {'axis', 'input', 'tensor'},
#  {'indices', 'tensor'},
#  {'name', 'optional', 'variable_scope'},
#  {'optional', 'returned'},
#  {'SOME_DTYPE', 'qint', 'quint'},
#  {'SOME_DTYPE', 'channels_first', 'channels_last'},
#  {'SOME_DTYPE', 'file'},
#  {'SOME_DTYPE', 'convolution'},
#  {'SOME_DTYPE', 'vector'},
#  {'SOME_DTYPE', 'keys'},
#  {'dtype', 'value'},
#  {'SOME_DTYPE', 'defaults', 'tf'},
#  {'SOME_DTYPE', 'input'},
#  {'batch', 'number'},
#  {'batch', 'size'},
#  {'dimension', 'order'},
#  {'batch', 'dimensions'},
#  {'dimensions', 'shape'},
#  {'tensor', 'true'},
#  {'batch', 'channels', 'shape'},
#  {'details', 'nn', 'see', 'tf'},
#  {'SOME_DTYPE', 'n'},
#  {'n', 'tensor'},
#  {'flagvalues', 'instance'},
#  {'arbitrary', 'tensor'},
#  {'SOME_DTYPE', 'optional', 'tf'},
#  {'corresponding', 'labels', 'optional'},
#  {'dtype', 'optional'},
#  {'SOME_DTYPE', 'tf'},
#  {'SOME_DTYPE', 'mapping'},
#  {'SOME_DTYPE', 'batch_size', 'shape'},
#  {'range', 'values'},
#  {'seed', 'used'},
#  {'must', 'type', 'x'},
#  {'none', 'value'},
#  {'batch', 'data', 'order'},
#  {'batch', 'channels', 'height', 'width'},
#  {'batch', 'data', 'format'},
#  {'data_format', 'details', 'dimension', 'order', 'see', 'value'},
#  {'batch', 'channels', 'd', 'height', 'width'},
#  {'d', 'length'},
#  {'valid', 'values'},
#  {'must', 'shape'},
#  {'nested', 'possibly'},
#  {'none', 'tensor'},
#  {'shape', 'tensor', 'whose'},
#  {'shape', 'tensor'},
#  {'optional', 'tf'},
#  {'optional', 'returned', 'tensor'},
#  {'SOME_DTYPE', 'qint'},
#  {'SOME_DTYPE', 'tensor', 'x'},
#  {'default', 'values'},
#  {'input', 'values'},
#  {'random', 'used'},
#  {'dilation', 'input'},
#  {'d', 'size', 'tensor'},
#  {'batch_size', 'd'},
#  {'dimensions', 'length', 'reduced', 'retains', 'true'},
#  {'along', 'dimension'},
#  {'dataset', 'tf'},
#  {'height', 'shape', 'width'},
#  {'section', 'see'},
#  {'function', 'input'},
#  {'n', 'values'},
#  {'index', 'tensor'},
#  {'padding', 'use'},
#  {'algorithm', 'use'},
#  {'currently', 'supported'},
#  {'channels', 'shape', 'tensor'},
#  {'dimension', 'first', 'tensor'},
#  {'broadcastable',
#   'corresponding',
#   'dimension',
#   'dimensions',
#   'e',
#   'either',
#   'labels',
#   'must',
#   'optional',
#   'rank',
#   'tensor',
#   'whose'},
#  {'SOME_DTYPE', 'optional', 'tf'},
#  {'SOME_DTYPE', 'qint', 'quint'},
#  {'SOME_DTYPE', 'input', 'tensor'},
#  {'SOME_DTYPE', 'tensor', 'tf'},
#  {'SOME_DTYPE', 'd', 'shape'},
#  {'SOME_DTYPE', 'width'},
#  {'SOME_DTYPE', 'corresponding'},
#  {'SOME_DTYPE', 'boxes'},
#  {'tensor', 'value'},
#  {'SOME_DTYPE', 'type'},
#  {'algorithm', 'padding', 'type', 'use'},
#  {'SOME_DTYPE', 'following', 'must', 'one', 'qint'},
#  {'SOME_DTYPE', 'none'},
#  {'data', 'input'},
#  {'data', 'output'},
#  {'batch', 'in_height', 'in_width'},
#  {'batch', 'data', 'format', 'order'},
#  {'data_format',
#   'details',
#   'determined',
#   'dimension',
#   'order',
#   'see',
#   'value'},
#  {'batch', 'channels', 'd', 'height', 'shape', 'width'},
#  {'default', 'set'},
#  {'dtype', 'x'},
#  {'broadcastable', 'dtype'},
#  {'SOME_DTYPE', 'tensor', 'tf'},
#  {'SOME_DTYPE', 'tf'},
#  {'batch', 'height', 'shape', 'width'},
#  {'inputs', 'shape'},
#  {'convolution', 'details', 'nn', 'returns', 'section', 'see', 'tf'},
#  {'channels_last', 'one'},
#  {'channels_first', 'one'},
#  {'SOME_DTYPE', 'nested'},
#  {'dimensions', 'n'},
#  {'d', 'n'},
#  {'input', 'size'},
#  {'alias', 'deprecated'},
#  {'channels', 'tensor'},
#  {'ground', 'truth'},
#  {'SOME_DTYPE', 'shape', 'tensor'},
#  {'representing', 'shape', 'tensor'},
#  {'d', 'tensor'},
#  {'SOME_DTYPE', 'shape'},
#  {'SOME_DTYPE', 'representing'},
#  {'SOME_DTYPE', 'batch_size', 'tensor'},
#  {'SOME_DTYPE', 'boxes', 'representing'},
#  {'input', 'value'},
#  {'type', 'value'},
#  {'defaults', 'first'},
#  {'dtype', 'type'},
#  {'create', 'used'},
#  {'SOME_DTYPE', 'non'},
#  {'SOME_DTYPE', 'must'},
#  {'SOME_DTYPE', 'following', 'must', 'one', 'qint', 'quint'},
#  {'cells', 'set'},
#  {'data', 'type'},
#  {'dimension', 'element'},
#  {'batch', 'dimensions'},
#  {'d', 'in_channels', 'shape', 'tensor'},
#  {'SOME_DTYPE', 'd', 'shape', 'tensor'},
#  {'SOME_DTYPE', 'd', 'type'},
#  {'d', 'depth'},
#  {'default', 'valid'},
#  {'default', 'none'},
#  {'rank', 'tensor'},
#  {'SOME_DTYPE', 'dtype', 'tf'},
#  {'SOME_DTYPE', 'tf'},
#  {'output', 'shape'},
#  {'d', 'shape', 'tensor'},
#  {'depth', 'shape'},
#  {'keras', 'variable'},
#  {'SOME_DTYPE', 'function'},
#  {'axis', 'deprecated'},
#  {'possibly', 'tensor'},
#  {'SOME_DTYPE', 'tensor'},
#  {'predictions', 'tensor', 'whose'},
#  {'channels', 'height', 'shape', 'tensor', 'width'},
#  {'d', 'shape', 'tensor'},
#  {'ref', 'tensor'},
#  {'num_classes', 'tensor'},
#  {'false', 'tensor'},
#  {'condition', 'tensor'},
#  {'name', 'optional', 'tensor'},
#  {'SOME_DTYPE', 'optional', 'tensor'},
#  {'SOME_DTYPE', 'optional', 'tf'},
#  {'SOME_DTYPE', 'd', 'shape', 'tensor'},
#  {'SOME_DTYPE', 'rank'},
#  {'SOME_DTYPE', 'first'},
#  {'SOME_DTYPE', 'update_op'},
#  {'SOME_DTYPE', 'weights'},
#  {'SOME_DTYPE', 'values'},
#  {'name', 'used'},
#  {'SOME_DTYPE', 'objects'},
#  {'input_tensor', 'must', 'range', 'rank'},
#  {'SOME_DTYPE', 'following', 'must', 'one', 'qint', 'quint'},
#  {'element', 'set'},
#  {'batch', 'data', 'in_channels'},
#  {'batch', 'must'},
#  {'batch', 'dimensions', 'shape'},
#  {'batch', 'dimensions', 'shape'},
#  {'batch', 'dimensions', 'shape'},
#  {'dimensions', 'shape'},
#  {'channels', 'd', 'shape', 'tensor'},
#  {'batch', 'd', 'height', 'shape', 'tensor', 'width'},
#  {'SOME_DTYPE', 'd', 'tensor', 'type'},
#  {'d', 'depth', 'shape'},
#  {'default', 'valid', 'values'},
#  {'dtype', 'tf'},
#  {'dtype', 'tensor'},
#  {'dtype', 'tf'},
#  {'data', 'dataset', 'tf'},
#  {'input', 'shape'},
#  {'channels', 'height', 'shape', 'width'},
#  {'height', 'shape', 'width'},
#  {'num_classes', 'shape'},
#  {'function', 'tensor'},
#  {'channels_first', 'channels_last', 'one'},
#  {'nested', 'structure'},
#  {'dimension', 'size', 'tensor'},
#  {'dimensions', 'spatial'},
#  {'SOME_DTYPE', 'bfloat'},
#  {'index', 'input'},
#  {'input', 'specifies'},
#  {'nested', 'possibly', 'tensor'},
#  {'SOME_DTYPE', 'cast'},
#  {'broadcastable', 'x'},
#  {'dimension', 'input', 'sliding', 'stride', 'tensor', 'window'},
#  {'SOME_DTYPE', 'shape', 'tensor', 'type'},
#  {'dimension', 'size', 'tensor'},
#  {'elements', 'tensor'},
#  {'name', 'used'},
#  {'name', 'optional', 'prefix', 'returned', 'tensor'},
#  {'SOME_DTYPE', 'added', 'collections', 'optional', 'update_op'},
#  {'optional', 'used'},
#  {'optional', 'type'},
#  {'SOME_DTYPE', 'single', 'tensor'},
#  {'SOME_DTYPE', 'along'},
#  {'SOME_DTYPE', 'path'},
#  {'SOME_DTYPE', 'created'},
#  {'SOME_DTYPE', 'ops'},
#  {'SOME_DTYPE', 'passed'},
#  {'value', 'values'},
#  {'SOME_DTYPE', 'value'},
#  {'flag', 'value'},
#  {'SOME_DTYPE', 'type'},
#  {'input', 'value'},
#  {'dimension', 'input'},
#  {'inputs', 'shape'},
#  {'input', 'range'},
#  {'SOME_DTYPE', 'bfloat', 'following', 'must', 'one'},
#  {'must', 'value'},
#  {'cells', 'dimension', 'element', 'filter', 'k', 'set', 'skipped'},
#  {'batch', 'd', 'tensor'},
#  {'dilation', 'dimension', 'factor', 'input'},
#  {'depth', 'dimensions'},
#  {'channels', 'd', 'height', 'shape', 'tensor', 'width'},
#  {'batch_size', 'd', 'tensor'},
#  {'operations', 'scope'},
#  {'SOME_DTYPE', 'dtype', 'tf'},
#  {'dtype', 'tf'},
#  {'batch', 'channels', 'height', 'shape', 'width'},
#  {'batch', 'channels', 'height', 'shape', 'width'},
#  {'batch', 'channels', 'height', 'shape', 'width'},
#  {'batch', 'channels', 'height', 'shape', 'width'},
#  {'corresponds', 'shape'},
#  {'m', 'shape'},
#  {'default', 'one'},
#  {'flag', 'instance'},
#  {'d', 'width'},
#  {'SOME_DTYPE', 'bfloat'},
#  {'tensor', 'vector'},
#  {'filter_height', 'filter_width'},
#  {'global', 'step'},
#  {'default', 'tensor'},
#  {'broadcastable', 'dtype', 'tensor'},
#  {'array', 'tensor'},
#  {'match', 'tensor'},
#  {'sequence', 'tensor'},
#  {'print', 'tensor'},
#  {'name', 'optional', 'returned'},
#  {'optional', 'prefix'},
#  {'dtype', 'optional', 'tf'},
#  {'SOME_DTYPE', 'dtype', 'optional'},
#  {'SOME_DTYPE', 'feature', 'values'},
#  {'SOME_DTYPE', 'representing', 'tensor'},
#  {'SOME_DTYPE', 'single'},
#  {'SOME_DTYPE', 'convolution'},
#  {'SOME_DTYPE', 'key'},
#  {'SOME_DTYPE', 'objects', 'tensor', 'type'},
#  {'SOME_DTYPE', 'channels_first', 'channels_last', 'one'},
#  {'SOME_DTYPE', 'height'},
#  {'SOME_DTYPE', 'window'},
#  {'SOME_DTYPE', 'optional'},
#  {'SOME_DTYPE', 'convolution', 'specifying'},
#  {'SOME_DTYPE', 'matrix'},
#  {'SOME_DTYPE', 'object'},
#  {'shape', 'value'},
#  {'dtype', 'type', 'value'},
#  {'SOME_DTYPE', 'type'},
#  {'negative', 'non'},
#  {'batch', 'inputs'},
#  {'SOME_DTYPE', 'following', 'must', 'one'},
#  {'SOME_DTYPE', 'bfloat', 'following', 'must', 'one'},
#  {'data', 'format', 'input'},
#  {'data', 'format'},
#  {'batch', 'format', 'in_channels'},
#  {'batch', 'depth', 'dilations', 'dimensions', 'must'},
#  {'dimensions', 'inputs'},
#  {'d', 'shape', 'tensor', 'type'},
#  {'d', 'python', 'tensor'},
#  {'d', 'shape', 'tensor'},
#  {'d', 'dimension', 'tensor'},
#  {'d', 'tensor'},
#  {'d', 'data_format'},
#  {'batch', 'default'},
#  {'output', 'shape'},
#  {'broadcastable', 'dtype', 'x'},
#  {'tensor', 'tf'},
#  {'behavior', 'tf'},
#  {'SOME_DTYPE', 'dtype', 'tf'},
#  {'channels_first', 'shape'},
#  {'filter_width', 'shape'},
#  {'out_channels', 'shape'},
#  {'function', 'returns'},
#  {'default', 'n', 'valid', 'values'},
#  {'dimension', 'last', 'size'},
#  {'channels_last', 'corresponds'},
#  {'channels_first', 'channels_last', 'corresponds'},
#  {'d', 'height'},
#  {'bias', 'vector'},
#  {'SOME_DTYPE', 'returns'},
#  {'almost', 'need', 'never', 'overridden'},
#  {'flag', 'flagvalues', 'instance'},
#  {'d', 'shape', 'tensor'},
#  {'tensor', 'used'},
#  {'tensor', 'type', 'value'},
#  {'condition', 'false', 'print', 'tensor'},
#  {'SOME_DTYPE', 'name'},
#  {'SOME_DTYPE', 'optional', 'tf'},
#  {'dtype', 'optional', 'tf'},
#  {'name', 'optional', 'returned', 'tensor'},
#  {'optional', 'value'},
#  {'SOME_DTYPE', 'return'},
#  {'SOME_DTYPE', 'bfloat'},
#  {'SOME_DTYPE', 'tensor'},
#  {'SOME_DTYPE', 'none'},
#  {'SOME_DTYPE', 'tensor', 'type'},
#  {'SOME_DTYPE', 'objects'},
#  {'SOME_DTYPE', 'channels_first', 'channels_last', 'default', 'one'},
#  {'SOME_DTYPE', 'nhwc'},
#  {'SOME_DTYPE', 'dataset'},
#  {'SOME_DTYPE', 'elements'},
#  {'SOME_DTYPE', 'represents'},
#  {'defaults', 'error'},
#  {'output', 'type'},
#  {'type', 'value'},
#  {'tensor', 'used'},
#  {'key', 'tensor'},
#  {'batch', 'inputs', 'shape'},
#  {'batch', 'inputs', 'shape'},
#  {'SOME_DTYPE', 'bfloat', 'following', 'must', 'one'},
#  {'must', 'size'},
#  {'batch', 'data', 'in_width'},
#  {'batch', 'inputs'},
#  {'dimensions', 'inputs', 'shape'},
#  {'d', 'height', 'shape', 'tensor', 'width'},
#  {'d', 'shape', 'tensor'},
#  {'d', 'output', 'tensor'},
#  {'d', 'length', 'tensor'},
#  {'d', 'tensor'},
#  {'d', 'must'},
#  {'batch', 'd', 'tensor'},
#  {'SOME_DTYPE', 'default'},
#  {'otherwise', 'true'},
#  {'input', 'true'},
#  {'SOME_DTYPE', 'dtype', 'tf'},
#  {'SOME_DTYPE', 'dtype', 'tf'},
#  {'SOME_DTYPE', 'dtype', 'tf'},
#  {'SOME_DTYPE', 'tf'},
#  {'SOME_DTYPE', 'tf'},
#  {'representing', 'tf'},
#  {'SOME_DTYPE', 'shape'},
#  {'batch', 'shape', 'tensor'},
#  {'channels_first', 'shape'},
#  {'filter_height', 'filter_width', 'shape'},
#  {'n', 'shape'},
#  {'data_format', 'shape'},
#  {'compat', 'see', 'tf', 'v'},
#  {'see', 'set_random_seed'},
#  {'python', 'type'},
#  {'single', 'tensor'},
#  {'number', 'representing'},
#  {'dimension', 'input', 'size'},
#  {'size', 'window'},
#  {'input', 'size', 'tensor'},
#  {'matches', 'whose'},
#  {'match', 'whose'},
#  {'d', 'height', 'width'},
#  {'height', 'tensor', 'width'},
#  {'entries', 'first'},
#  {'axis', 'index', 'input'},
#  {'error', 'message'},
#  {'arguments', 'keyword'},
#  {'last', 'must'},
#  {'ground', 'tensor', 'truth'},
#  {'keras', '~'},
#  {'learning', 'rate'},
#  {'SOME_DTYPE', 'tensor'},
#  {'in_channels', 'shape', 'tensor', 'type'},
#  {'batch', 'shape', 'tensor'},
#  {'last', 'tensor'},
#  {'returns', 'tensor'},
#  {'dtype', 'python', 'tensor', 'type', 'value'},
#  {'dtype', 'tensor', 'x'},
#  {'data_format', 'tensor'},
#  {'nested', 'tensor'},
#  {'optional', 'values'},
#  {'SOME_DTYPE', 'dtype', 'optional', 'tf'},
#  {'SOME_DTYPE', 'defaults'},
#  {'SOME_DTYPE', 'specifying'},
#  {'SOME_DTYPE', 'convolution', 'specifying'},
#  {'SOME_DTYPE', 'supported'},
#  {'SOME_DTYPE', 'identifying'},
#  {'SOME_DTYPE', 'objects', 'tensor'},
#  {'SOME_DTYPE', 'shape', 'tensor'},
#  {'SOME_DTYPE', 'indices'},
#  {'SOME_DTYPE', 'match'},
#  {'SOME_DTYPE', 'array'},
#  {'SOME_DTYPE', 'e'},
#  {'SOME_DTYPE', 'true'},
#  {'SOME_DTYPE', 'threshold'},
#  {'SOME_DTYPE', 'returns', 'tensor'},
#  {'SOME_DTYPE', 'flag', 'name'},
#  {'SOME_DTYPE', 'serialized'},
#  {'SOME_DTYPE', 'keyword'},
#  {'return', 'tensor'},
#  {'dimensions', 'tensor', 'values'},
#  {'dimension', 'values'},
#  {'predictions', 'values'},
#  {'defaults', 'error', 'message'},
#  {'input', 'type'},
#  {'number', 'training'},
#  {'example', 'number'},
#  {'SOME_DTYPE', 'bfloat', 'following', 'must', 'one', 'qint', 'quint'},
#  {'match', 'must', 'predictions'},
#  {'none', 'used'},
#  {'dimension', 'shape'},
#  {'dimensions', 'tensor'},
#  {'batch', 'd', 'height', 'shape', 'tensor', 'width'},
#  {'batch', 'channels', 'd', 'height', 'shape', 'tensor', 'width'},
#  {'d', 'shape', 'tensor'},
#  {'d', 'dimension', 'size', 'tensor'},
#  {'d', 'representing', 'tensor'},
#  {'d', 'tensor', 'value'},
#  {'SOME_DTYPE', 'batch_size', 'd'},
#  {'d', 'height', 'tensor', 'width'},
#  {'channels', 'd', 'tensor'},
#  {'containing', 'd'},
#  {'array', 'd'},
#  {'d', 'filter_width'},
#  {'default', 'n'},
#  {'n', 'rank'},
#  {'SOME_DTYPE', 'output'},
#  {'SOME_DTYPE', 'tf'},
#  {'SOME_DTYPE', 'dtype', 'tf'},
#  {'SOME_DTYPE', 'dtype', 'tf'},
#  {'experimental', 'tf'},
#  {'batch', 'shape', 'tensor'},
#  {'filter_width', 'in_channels', 'shape'},
#  {'dimension', 'shape'},
#  {'behavior', 'see', 'tf'},
#  {'keras', 'returned', 'variable'},
#  {'SOME_DTYPE', 'python'},
#  {'function', 'used'},
#  {'default', 'either'},
#  {'SOME_DTYPE', 'either'},
#  {'either', 'tensor'},
#  {'dimension', 'single'},
#  {'representing', 'tensor'},
#  {'dimension', 'input', 'size', 'tensor'},
#  {'dimension', 'size', 'window'},
#  {'axis', 'deprecated', 'name'},
#  {'batch',
#   'channels_first',
#   'channels_last',
#   'corresponds',
#   'dimensions',
#   'inputs',
#   'ordering',
#   'shape'},
#  {'dimension', 'specifies'},
#  {'axis', 'compute'},
#  {'keyword', 'passed'},
#  {'ground', 'predictions', 'tensor', 'truth'},
#  {'SOME_DTYPE', 'vector'},
#  {'flag', 'flagvalues', 'instance', 'registered'},
#  {'SOME_DTYPE', 'tensor'},
#  {'batch_size', 'shape', 'tensor', 'type'},
#  {'predictions', 'shape', 'tensor'},
#  {'shape', 'tensor', 'whose'},
#  {'batch', 'shape', 'tensor'},
#  {'broadcastable', 'tensor', 'x'},
#  {'output', 'tensor'},
#  {'returns', 'tensor'},
#  {'indexedslices', 'tensor'},
#  {'k', 'tensor'},
#  {'serialized', 'tensor'},
#  {'SOME_DTYPE', 'dtype', 'optional', 'tf'},
#  {'optional', 'variable'},
#  {'SOME_DTYPE', 'value'},
#  {'SOME_DTYPE', 'dtype', 'tensor'},
#  {'SOME_DTYPE', 'compute'},
#  {'SOME_DTYPE', 'operation'},
#  {'SOME_DTYPE', 'number', 'representing'},
#  {'SOME_DTYPE', 'layer'},
#  {'SOME_DTYPE', 'whose'},
#  {'SOME_DTYPE', 'non'},
#  {'SOME_DTYPE', 'step'},
#  {'SOME_DTYPE', 'considered'},
#  {'SOME_DTYPE', 'defining'},
#  {'SOME_DTYPE', 'broadcastable'},
#  {'SOME_DTYPE', 'embedding'},
#  {'used', 'value'},
#  {'given', 'value'},
#  {'tf', 'values'},
#  {'defaults', 'value'},
#  {'defaults', 'entries', 'error', 'first', 'message'},
#  {'defaults', 'x'},
#  {'returned', 'type'},
#  {'dimensions', 'input'},
#  {'batch', 'input'},
#  {'elements', 'number'},
#  {'classes', 'number', 'target'},
#  {'known', 'must'},
#  {'batch', 'in_channels', 'in_width'},
#  {'batch', 'format', 'in_width'},
#  {'dimensions', 'predictions'},
#  {'batch_size', 'd', 'shape', 'tensor'},
#  {'d', 'in_channels', 'shape', 'tensor', 'type'},
#  {'d', 'data', 'tensor'},
#  {'batch', 'channels', 'd', 'height', 'tensor', 'width'},
#  {'batch', 'd', 'depth'},
#  {'d', 'filter_height', 'filter_width'},
#  {'default', 'false'},
#  {'less', 'true'},
#  {'dtype', 'returned'},
#  {'object', 'tf'},
#  {'batch', 'depth', 'shape'},
#  {'height', 'shape', 'tensor', 'width'},
#  {'channels', 'shape', 'tensor'},
#  {'shape', 'type'},
#  {'filter_height', 'filter_width', 'in_channels', 'shape'},
#  {'d', 'height', 'shape', 'width'},
#  {'function', 'variable'},
#  {'SOME_DTYPE', 'may'},
#  {'structure', 'tensor'},
#  {'c', 'n'},
#  {'dimension', 'input', 'size', 'window'},
#  {'args', 'keyword'},
#  {'generator', 'random'},
#  {'h', 'w'},
#  {'kernel', 'matrix'},
#  {'ncdhw', 'ndhwc'},
#  {'along', 'tensor'},
#  {'n', 'rank', 'tensor'},
#  {'dimension', 'tensor'},
#  {'shape', 'tensor', 'type'},
#  {'function', 'tensor'},
#  {'possibly', 'tensor'},
#  {'name', 'use'},
#  {'optional', 'use'},
#  {'SOME_DTYPE', 'objects'},
#  {'SOME_DTYPE', 'batch'},
#  {'SOME_DTYPE', 'batch_size', 'shape', 'tensor'},
#  {'SOME_DTYPE', 'broadcastable', 'dtype', 'tensor', 'x'},
#  {'SOME_DTYPE', 'representing', 'tf'},
#  {'SOME_DTYPE', 'empty'},
#  {'SOME_DTYPE', 'model'},
#  {'SOME_DTYPE', 'keras'},
#  {'SOME_DTYPE', 'height', 'width'},
#  {'SOME_DTYPE', 'nchw', 'nhwc'},
#  {'SOME_DTYPE', 'csv'},
#  {'SOME_DTYPE', 'format'},
#  {'SOME_DTYPE', 'random'},
#  {'SOME_DTYPE', 'd', 'tensor'},
#  {'SOME_DTYPE', 'row'},
#  {'SOME_DTYPE', 'returns'},
#  {'SOME_DTYPE', 'false'},
#  {'SOME_DTYPE', 'args', 'extra', 'keyword', 'passed'},
#  {'SOME_DTYPE', 'help', 'message'},
#  {'dimension', 'value'},
#  {'must', 'value'},
#  {'quantized', 'value'},
#  ...]

# %%
{'d','tensor'} in set_list
# Out:
# True
