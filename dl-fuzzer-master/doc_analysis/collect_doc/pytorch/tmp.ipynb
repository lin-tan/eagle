# %%
import sys
sys.path.insert(0,'..')
from parse_utils import *
import bs4
from bs4 import BeautifulSoup

# %%
path = '/Users/danning/Desktop/deepflaw/DeepFlaw-Code/doc_analysis/collect_doc/pytorch/doc1.5_source/'
file = 'torch.html'

# %%
soup = read_soup(path+file)

# %%
body = soup.find(class_='pytorch-container')

# %%
body.get_text()
# Out:
# '\n\n\n\n\n\n\n          \n            Docs\n          \n         >\n      \ntorch\n\n\n\n\n\n\n\n          Shortcuts\n        \n\n\n\n\n\n\n\ntorch¶\nThe torch package contains data structures for multi-dimensional\ntensors and mathematical operations over these are defined.\nAdditionally, it provides many utilities for efficient serializing of\nTensors and arbitrary types, and other useful utilities.\nIt has a CUDA counterpart, that enables you to run your tensor computations\non an NVIDIA GPU with compute capability >= 3.0.\n\nTensors¶\n\n\ntorch.is_tensor(obj)[source]¶\nReturns True if obj is a PyTorch tensor.\n\nParameters\nobj (Object) – Object to test\n\n\n\n\n\ntorch.is_storage(obj)[source]¶\nReturns True if obj is a PyTorch storage object.\n\nParameters\nobj (Object) – Object to test\n\n\n\n\n\ntorch.is_complex(input) -> (bool)¶\nReturns True if the data type of input is a complex data type i.e.,\none of torch.complex64, and torch.complex128.\n\nParameters\ninput (Tensor) – 
# ...

# %%
len(body.get_text().split())
# Out:
# 38999

# %%
len('tf.boo_sdf'.split())
# Out:
# 1

# %%
path= '/Users/danning/Desktop/deepflaw/DeepFlaw-Code/doc_analysis/collect_doc/tf/doc2.1source/'
file = 'tf.sparse.transpose.html'

# %%
soup= soup = read_soup(path+file)

# %%
body = soup.find_all(class_='devsite-article-body')

# %%
body
# Out:
# [<div class="devsite-article-body clearfix">
#  <p></p>
#  <!-- DO NOT EDIT! Automatically generated file. -->
#  <!-- Insert buttons and diff -->
#  <table align="left" class="tfo-notebook-buttons tfo-api">
#  <td>
#  <a href="/versions/r1.15/api_docs/python/tf/sparse/transpose" target="_blank">
#  <img src="https://www.tensorflow.org/images/tf_logo_32px.png"/>
#    TensorFlow 1 version</a>
#  </td>
#  <td>
#  <a href="https://github.com/tensorflow/tensorflow/blob/v2.1.0/tensorflow/python/ops/sparse_ops.py#L2540-L2599" target="_blank">
#  <img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png"/>
#      View source on GitHub
#    </a>
#  </td></table>
#  <p>Transposes a <code dir="ltr" translate="no">SparseTensor</code></p>
#  <section class="expandable">
#  <h4 class="showalways" data-text="View aliases" id="view-aliases" tabindex="0">View aliases</h4>
#  <p>
#  <b>Compat aliases for migration</b>
#  </p><p>See
# ...
